# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
filpkart_url="https://www.flipkart.com/search?q="+"iphone15"

# %%
filpkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone15'

# %%
urlclient=urlopen(filpkart_url)

# %%
urlclient

# %%
filpkart_page=urlclient.read()

# %%
filpkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.9e9635.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
filpkart_html=bs(filpkart_page,'html.parser')

# %%
filpkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox=filpkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:3]

# %%
product_link="https://www.flipkart.com"+bigbox[3].div.div.div.a['href']

# %%
product_link
# Out:
# 'https://www.flipkart.com/apple-iphone-15-plus-blue-128-gb/p/itm4022c14383050?pid=MOBGTAGPE4F2HAW7&lid=LSTMOBGTAGPE4F2HAW7NDYSPY&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=4f1c7de8-bfdb-48c2-b79e-a7e31659c7c8.MOBGTAGPE4F2HAW7.SEARCH&ppt=None&ppn=None&ssid=gllnf0sbxs0000001709633660370&qH=1827ac0d826493c5'

# %%
product_req=requests.get(product_link)

# %%
product_html=bs(product_req.text,'html.parser')

# %%
comment_box=product_html.findAll("div",{"class":"_16PBlm"})

# %%
comment_box[1].div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Anshul Duhan'

# %%
len(comment_box)
# Out:
# 11

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Sagar Behera
# Anshul Duhan
# Flipkart Customer
# madhusudhana  R
# Bibhu Bisoi
# Avinan Vaidya
# Anirudhya  Ghosh
# Akhtar Raza
# Jackson .
# Flipkart Customer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.findAll('p',{'class':"_2-N8zT"})[0].text

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2-N8zT"})[0].text)

# %%
for i in comment_box:
    print(i.div.div.div.div.text)

# %%
comment_box[0].div.div.findAll('div',{'class':''})[0].div.text

# %%
for i in comment_box
    print(i.div.div.findAll('div',{'class':''})[0].div.text)

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text,end="     ,")
    print(i.div.div.find_all("p",{"class":"_2-N8zT"})[0].text,end="     ,")
    print(i.div.div.findAll('div',{'class':''})[0].div.text,end="       ,")
    print(i.div.div.div.div.text)

# %%
for i in bigbox:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
